# %% [markdown]
# # Explore data and prototype logic — not run the system.
#
# - LOAD CSV data
# - PERFORM EDA (stats, distributions, correlations)
# - TEST feature engineering ideas
# - TRAIN and evaluate ML model
# - OPTIONALLY import functions from src for experiments
